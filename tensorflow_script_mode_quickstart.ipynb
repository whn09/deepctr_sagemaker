# %% [markdown]
# # Using TensorFlow Scripts in SageMaker - Quickstart
#
# Starting with TensorFlow version 1.11, you can use SageMaker's TensorFlow containers to train TensorFlow scripts the same way you would train outside SageMaker. This feature is named **Script Mode**.
#
# This example uses
# [Multi-layer Recurrent Neural Networks (LSTM, RNN) for character-level language models in Python using Tensorflow](https://github.com/sherjilozair/char-rnn-tensorflow).
# You can use the same technique for other scripts or repositories, including
# [TensorFlow Model Zoo](https://github.com/tensorflow/models) and
# [TensorFlow benchmark scripts](https://github.com/tensorflow/benchmarks/tree/master/scripts/tf_cnn_benchmarks).

# %% [markdown]
# ## Test locally using SageMaker Python SDK TensorFlow Estimator

# %% [markdown]
# You can use the SageMaker Python SDK [`TensorFlow`](https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/tensorflow/README.rst#training-with-tensorflow) estimator to easily train locally and in SageMaker.
#
# Let's start by setting the training script arguments `--num_epochs` and `--data_dir` as hyperparameters. Remember that we don't need to provide `--model_dir`:

# %%
from sagemaker import get_execution_role

role = get_execution_role()

# %%
hyperparameters = {'train_steps': 10}

# %% [markdown]
# This notebook shows how to use the SageMaker Python SDK to run your code in a local container before deploying to SageMaker's managed training or hosting environments. Just change your estimator's train_instance_type to local or local_gpu. For more information, see: https://github.com/aws/sagemaker-python-sdk#local-mode.
#
# In order to use this feature you'll need to install docker-compose (and nvidia-docker if training with a GPU). Running following script will install docker-compose or nvidia-docker-compose and configure the notebook environment for you.
#
# Note, you can only run a single local notebook at a time.

# %%
# !/bin/bash ./utils/setup.sh
# Out:
# The user has root access.
# nvidia-docker2 already installed. We are good to go!
# SageMaker instance route table setup is ok. We are good to go.
# SageMaker instance routing for Docker is ok. We are good to go!

# %% [markdown]
# To train locally, you set `train_instance_type` to [local](https://github.com/aws/sagemaker-python-sdk#local-mode):

# %%
import subprocess

train_instance_type='local'

if subprocess.call('nvidia-smi') == 0:
    ## Set type to GPU if one is present
    train_instance_type = 'local_gpu'
    
print("Train instance type = " + train_instance_type)
# Out:
# Train instance type = local_gpu

# %% [markdown]
# We create the `TensorFlow` Estimator, passing the `git_config` argument and the flag `script_mode=True`. Note that we are using Git integration here, so `source_dir` should be a relative path inside the Git repo; otherwise it should be a relative or absolute local path. the `Tensorflow` Estimator is created as following:

# %%
import os

import sagemaker
from sagemaker.tensorflow import TensorFlow


estimator = TensorFlow(entry_point='train.py',
                       source_dir='.',
                       train_instance_type=train_instance_type,
                       train_instance_count=1,
                       hyperparameters=hyperparameters,
                       role=role,
                       framework_version='2.2.0',
                       py_version='py37',
                       script_mode=True,
                       model_dir='/opt/ml/model')
# Out:
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# To start a training job, we call `estimator.fit(inputs)`, where inputs is a dictionary where the keys, named **channels**,
# have values pointing to the data location. `estimator.fit(inputs)` downloads the TensorFlow container with TensorFlow Python 3, CPU version, locally and simulates a SageMaker training job.
# When training starts, the TensorFlow container executes **train.py**, passing `hyperparameters` and `model_dir` as script arguments, executing the example as follows:
# ```bash
# python -m train --num-epochs 1 --data_dir /opt/ml/input/data/training --model_dir /opt/ml/model
# ```

# %%
inputs = {'training': f'file:///home/ec2-user/SageMaker/deepctr_sagemaker/data/'}

estimator.fit(inputs)
# Out:
# Creating tmpzojpgd0s_algo-1-m28iz_1 ...
# Attaching to tmpzojpgd0s_algo-1-m28iz_12mdone
# algo-1-m28iz_1  | 2021-01-09 18:10:24,352 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# algo-1-m28iz_1  | 2021-01-09 18:10:24,563 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# algo-1-m28iz_1  | /usr/local/bin/python3.7 -m pip install -r requirements.txt
# algo-1-m28iz_1  | Collecting deepctr[gpu]
# algo-1-m28iz_1  |   Downloading deepctr-0.8.3-py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 14.9 MB/s eta 0:00:01
# algo-1-m28iz_1  | Requirement already satisfied: pandas in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (1.0.3)
# algo-1-m28iz_1  | Requirement already satisfied: sklearn in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (0.0)
# algo-1-m28iz_1  | Requirement already satisfied: requests in /usr/local/lib/python3.7/site-packages (from deepctr[gpu]->-r requirements.txt (line 1)) (2.23.0)
# algo-1-m28iz_1  | Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.7/site-packages (from deepctr[gpu]->-r requirements.txt (line 1)) (2.10.0)
# algo-1-m28iz_1  | Requirement already satisfied: tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu" in /usr/local/lib/python3.7/site-packages (from deepctr[gpu]->-r requirements.txt (line 1)) (2.2.0)
# algo-1-m28iz_1  | Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (1.19.1)
# algo-1-m28iz_1  | Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (2020.1)
# algo-1-m28iz_1  | Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (2.8.1)
# algo-1-m28iz_1  | Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/site-packages (from sklearn->-r requirements.txt (line 3)) (0.23.0)
# algo-1-m28iz_1  | Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests->deepctr[gpu]->-r requirements.txt (line 1)) (2.10)
# algo-1-m28iz_1  | Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests->deepctr[gpu]->-r requirements.txt (line 1)) (1.25.10)
# algo-1-m28iz_1  | Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests->deepctr[gpu]->-r requirements.txt (line 1)) (3.0.4)
# algo-1-m28iz_1  | Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests->deepctr[gpu]->-r requirements.txt (line 1)) (2020.6.20)
# algo-1-m28iz_1  | Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from h5py==2.10.0->deepctr[gpu]->-r requirements.txt (line 1)) (1.15.0)
# algo-1-m28iz_1  | Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.6.3)
# algo-1-m28iz_1  | Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.2.0)
# algo-1-m28iz_1  | Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.31.0)
# algo-1-m28iz_1  | Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.10.0)
# algo-1-m28iz_1  | Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.35.1)
# algo-1-m28iz_1  | Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (2.2.2)
# algo-1-m28iz_1  | Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.3.3)
# algo-1-m28iz_1  | Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.4.1)
# algo-1-m28iz_1  | Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (2.2.0)
# algo-1-m28iz_1  | Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.1.0)
# algo-1-m28iz_1  | Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.12.1)
# algo-1-m28iz_1  | Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.13.0)
# algo-1-m28iz_1  | Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.3.0)
# algo-1-m28iz_1  | Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.1.2)
# algo-1-m28iz_1  | Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 3)) (0.16.0)
# algo-1-m28iz_1  | Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 3)) (2.1.0)
# algo-1-m28iz_1  | Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.21.0)
# algo-1-m28iz_1  | Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.4.1)
# algo-1-m28iz_1  | Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.2.2)
# algo-1-m28iz_1  | Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (50.1.0)
# algo-1-m28iz_1  | Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.7.0)
# algo-1-m28iz_1  | Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.0.1)
# algo-1-m28iz_1  | Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (4.1.1)
# algo-1-m28iz_1  | Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in /usr/local/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (4.5)
# algo-1-m28iz_1  | Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.2.8)
# algo-1-m28iz_1  | Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.3.0)
# algo-1-m28iz_1  | Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.7.0)
# algo-1-m28iz_1  | Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.4.8)
# algo-1-m28iz_1  | Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.1.0)
# algo-1-m28iz_1  | Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.1.0)
# algo-1-m28iz_1  | Installing collected packages: deepctr
# algo-1-m28iz_1  | Successfully installed deepctr-0.8.3
# algo-1-m28iz_1  | 2021-01-09 18:10:25,935 sagemaker-training-toolkit INFO     Invoking user script
# algo-1-m28iz_1  |
# algo-1-m28iz_1  | Training Env:
# algo-1-m28iz_1  |
# algo-1-m28iz_1  | {
# algo-1-m28iz_1  |     "additional_framework_parameters": {},
# algo-1-m28iz_1  |     "channel_input_dirs": {
# algo-1-m28iz_1  |         "training": "/opt/ml/input/data/training"
# algo-1-m28iz_1  |     },
# algo-1-m28iz_1  |     "current_host": "algo-1-m28iz",
# algo-1-m28iz_1  |     "framework_module": "sagemaker_tensorflow_container.training:main",
# algo-1-m28iz_1  |     "hosts": [
# algo-1-m28iz_1  |         "algo-1-m28iz"
# algo-1-m28iz_1  |     ],
# algo-1-m28iz_1  |     "hyperparameters": {
# algo-1-m28iz_1  |         "train_steps": 10,
# algo-1-m28iz_1  |         "model_dir": "/opt/ml/model"
# algo-1-m28iz_1  |     },
# algo-1-m28iz_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-m28iz_1  |     "input_data_config": {
# algo-1-m28iz_1  |         "training": {
# algo-1-m28iz_1  |             "TrainingInputMode": "File"
# algo-1-m28iz_1  |         }
# algo-1-m28iz_1  |     },
# algo-1-m28iz_1  |     "input_dir": "/opt/ml/input",
# algo-1-m28iz_1  |     "is_master": true,
# algo-1-m28iz_1  |     "job_name": "tensorflow-training-2021-01-09-18-10-20-124",
# algo-1-m28iz_1  |     "log_level": 20,
# algo-1-m28iz_1  |     "master_hostname": "algo-1-m28iz",
# algo-1-m28iz_1  |     "model_dir": "/opt/ml/model",
# algo-1-m28iz_1  |     "module_dir": "s3://sagemaker-us-east-1-579019700964/tensorflow-training-2021-01-09-18-10-20-124/source/sourcedir.tar.gz",
# algo-1-m28iz_1  |     "module_name": "train",
# algo-1-m28iz_1  |     "network_interface_name": "eth0",
# algo-1-m28iz_1  |     "num_cpus": 8,
# algo-1-m28iz_1  |     "num_gpus": 1,
# algo-1-m28iz_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-m28iz_1  |     "output_dir": "/opt/ml/output",
# algo-1-m28iz_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-m28iz_1  |     "resource_config": {
# algo-1-m28iz_1  |         "current_host": "algo-1-m28iz",
# algo-1-m28iz_1  |         "hosts": [
# algo-1-m28iz_1  |             "algo-1-m28iz"
# algo-1-m28iz_1  |         ]
# algo-1-m28iz_1  |     },
# algo-1-m28iz_1  |     "user_entry_point": "train.py"
# algo-1-m28iz_1  | }
# algo-1-m28iz_1  |
# algo-1-m28iz_1  | Environment variables:
# algo-1-m28iz_1  |
# algo-1-m28iz_1  | SM_HOSTS=["algo-1-m28iz"]
# algo-1-m28iz_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-m28iz_1  | SM_HPS={"model_dir":"/opt/ml/model","train_steps":10}
# algo-1-m28iz_1  | SM_USER_ENTRY_POINT=train.py
# algo-1-m28iz_1  | SM_FRAMEWORK_PARAMS={}
# algo-1-m28iz_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-m28iz","hosts":["algo-1-m28iz"]}
# algo-1-m28iz_1  | SM_INPUT_DATA_CONFIG={"training":{"TrainingInputMode":"File"}}
# algo-1-m28iz_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-m28iz_1  | SM_CHANNELS=["training"]
# algo-1-m28iz_1  | SM_CURRENT_HOST=algo-1-m28iz
# algo-1-m28iz_1  | SM_MODULE_NAME=train
# algo-1-m28iz_1  | SM_LOG_LEVEL=20
# algo-1-m28iz_1  | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# algo-1-m28iz_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-m28iz_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-m28iz_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-m28iz_1  | SM_NUM_CPUS=8
# algo-1-m28iz_1  | SM_NUM_GPUS=1
# algo-1-m28iz_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-m28iz_1  | SM_MODULE_DIR=s3://sagemaker-us-east-1-579019700964/tensorflow-training-2021-01-09-18-10-20-124/source/sourcedir.tar.gz
# algo-1-m28iz_1  | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1-m28iz","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-m28iz"],"hyperparameters":{"model_dir":"/opt/ml/model","train_steps":10},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2021-01-09-18-10-20-124","log_level":20,"master_hostname":"algo-1-m28iz","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-579019700964/tensorflow-training-2021-01-09-18-10-20-124/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-m28iz","hosts":["algo-1-m28iz"]},"user_entry_point":"train.py"}
# algo-1-m28iz_1  | SM_USER_ARGS=["--model_dir","/opt/ml/model","--train_steps","10"]
# algo-1-m28iz_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-m28iz_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-m28iz_1  | SM_HP_TRAIN_STEPS=10
# algo-1-m28iz_1  | SM_HP_MODEL_DIR=/opt/ml/model
# algo-1-m28iz_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# algo-1-m28iz_1  |
# algo-1-m28iz_1  | Invoking script with the following command:
# algo-1-m28iz_1  |
# algo-1-m28iz_1  | /usr/local/bin/python3.7 train.py --model_dir /opt/ml/model --train_steps 10
# algo-1-m28iz_1  |
# algo-1-m28iz_1  |
# algo-1-m28iz_1  | cuda_visible_devices: 0 gpus: 1
# algo-1-m28iz_1  | Epoch 1/10
# algo-1-m28iz_1  | 1/1 - 1s - loss: 0.7803 - binary_crossentropy: 0.7803 - val_loss: 0.7653 - val_binary_crossentropy: 0.7653
# algo-1-m28iz_1  | Epoch 2/10
# algo-1-m28iz_1  | 1/1 - 0s - loss: 0.7573 - binary_crossentropy: 0.7573 - val_loss: 0.7510 - val_binary_crossentropy: 0.7510
# algo-1-m28iz_1  | Epoch 3/10
# algo-1-m28iz_1  | 1/1 - 0s - loss: 0.7352 - binary_crossentropy: 0.7352 - val_loss: 0.7374 - val_binary_crossentropy: 0.7374
# algo-1-m28iz_1  | Epoch 4/10
# algo-1-m28iz_1  | 1/1 - 0s - loss: 0.7140 - binary_crossentropy: 0.7139 - val_loss: 0.7243 - val_binary_crossentropy: 0.7243
# algo-1-m28iz_1  | Epoch 5/10
# algo-1-m28iz_1  | 1/1 - 0s - loss: 0.6935 - binary_crossentropy: 0.6935 - val_loss: 0.7117 - val_binary_crossentropy: 0.7117
# algo-1-m28iz_1  | Epoch 6/10
# algo-1-m28iz_1  | 1/1 - 0s - loss: 0.6738 - binary_crossentropy: 0.6738 - val_loss: 0.6994 - val_binary_crossentropy: 0.6994
# algo-1-m28iz_1  | Epoch 7/10
# algo-1-m28iz_1  | 1/1 - 0s - loss: 0.6545 - binary_crossentropy: 0.6545 - val_loss: 0.6874 - val_binary_crossentropy: 0.6874
# algo-1-m28iz_1  | Epoch 8/10
# algo-1-m28iz_1  | 1/1 - 0s - loss: 0.6356 - binary_crossentropy: 0.6356 - val_loss: 0.6756 - val_binary_crossentropy: 0.6756
# algo-1-m28iz_1  | Epoch 9/10
# algo-1-m28iz_1  | 1/1 - 0s - loss: 0.6169 - binary_crossentropy: 0.6169 - val_loss: 0.6643 - val_binary_crossentropy: 0.6643
# algo-1-m28iz_1  | Epoch 10/10
# algo-1-m28iz_1  | 1/1 - 0s - loss: 0.5984 - binary_crossentropy: 0.5983 - val_loss: 0.6532 - val_binary_crossentropy: 0.6532
# algo-1-m28iz_1  | test LogLoss 0.6319
# algo-1-m28iz_1  | test AUC 0.6237
# algo-1-m28iz_1  | 2021-01-09 18:10:41,369 sagemaker_tensorflow_container.training WARNING  Your model will NOT be servable with SageMaker TensorFlow Serving container. The model artifact was not saved in the TensorFlow SavedModel directory structure:
# algo-1-m28iz_1  | https://www.tensorflow.org/guide/saved_model#structure_of_a_savedmodel_directory
# algo-1-m28iz_1  | 2021-01-09 18:10:41,370 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# tmpzojpgd0s_algo-1-m28iz_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# Let's explain the values of `--data_dir` and `--model_dir` with more details:
#
# - **/opt/ml/input/data/training** is the directory inside the container where the training data is downloaded. The data is downloaded to this folder because `training` is the channel name defined in ```estimator.fit({'training': inputs})```. See [training data](https://docs.aws.amazon.com/sagemaker/latest/dg/your-algorithms-training-algo.html#your-algorithms-training-algo-running-container-trainingdata) for more information.
#
# - **/opt/ml/model** use this directory to save models, checkpoints, or any other data. Any data saved in this folder is saved in the S3 bucket defined for training. See [model data](https://docs.aws.amazon.com/sagemaker/latest/dg/your-algorithms-training-algo.html#your-algorithms-training-algo-envvariables) for more information.
#
# ### Reading additional information from the container
#
# Often, a user script needs additional information from the container that is not available in ```hyperparameters```.
# SageMaker containers write this information as **environment variables** that are available inside the script.
#
# For example, the example above can read information about the `training` channel provided in the training job request by adding the environment variable `SM_CHANNEL_TRAINING` as the default value for the `--data_dir` argument:
#
# ```python
# if __name__ == '__main__':
#   parser = argparse.ArgumentParser()
#   # reads input channels training and testing from the environment variables
#   parser.add_argument('--data_dir', type=str, default=os.environ['SM_CHANNEL_TRAINING'])
# ```
#
# Script mode displays the list of available environment variables in the training logs. You can find the [entire list here](https://github.com/aws/sagemaker-containers/blob/master/README.rst#list-of-provided-environment-variables-by-sagemaker-containers).

# %% [markdown]
# # Training in SageMaker

# %% [markdown]
# After you test the training job locally, upload the dataset to an S3 bucket so SageMaker can access the data during training:

# %%
import sagemaker

inputs = sagemaker.Session().upload_data(path='/home/ec2-user/SageMaker/deepctr_sagemaker/data', key_prefix='DEMO-tensorflow-deepctr')
print(inputs)
# Out:
# s3://sagemaker-us-east-1-579019700964/DEMO-tensorflow-deepctr

# %% [markdown]
# The returned variable inputs above is a string with a S3 location which SageMaker Tranining has permissions
# to read data from.

# %% [markdown]
# To train in SageMaker:
# - change the estimator argument `train_instance_type` to any SageMaker ml instance available for training.
# - set the `training` channel to a S3 location.

# %%
estimator = TensorFlow(entry_point='train.py',
                       source_dir='.',
                       train_instance_type='ml.p3.8xlarge', # Executes training in a ml.p2.xlarge/ml.p3.2xlarge/ml.p3.8xlarge instance
                       train_instance_count=1,
                       hyperparameters=hyperparameters,
                       role=role,
                       framework_version='2.2.0',
                       py_version='py37',
                       script_mode=True,
                       model_dir='/opt/ml/model')

estimator.fit({'training': inputs})
# Out:
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-01-09 18:29:56 Starting - Starting the training job...
# 2021-01-09 18:30:19 Starting - Launching requested ML instancesProfilerReport-1610216996: InProgress
# .........
# 2021-01-09 18:31:40 Starting - Preparing the instances for training......
# 2021-01-09 18:32:52 Downloading - Downloading input data
# 2021-01-09 18:32:52 Training - Downloading the training image.........
# 2021-01-09 18:34:22 Training - Training image download completed. Training in progress..2021-01-09 18:34:21,660 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-01-09 18:34:22,084 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /usr/local/bin/python3.7 -m pip install -r requirements.txt
# Collecting deepctr[gpu]
#   Downloading deepctr-0.8.3-py3-none-any.whl (114 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (1.0.3)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/site-packages (from deepctr[gpu]->-r requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.7/site-packages (from deepctr[gpu]->-r requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu" in /usr/local/lib/python3.7/site-packages (from deepctr[gpu]->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (1.19.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (2020.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/site-packages (from sklearn->-r requirements.txt (line 3)) (0.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests->deepctr[gpu]->-r requirements.txt (line 1)) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests->deepctr[gpu]->-r requirements.txt (line 1)) (1.25.10)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests->deepctr[gpu]->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests->deepctr[gpu]->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from h5py==2.10.0->deepctr[gpu]->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.3.3)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.31.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.35.1)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.13.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.7.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (50.1.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.21.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in /usr/local/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (4.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.1.0)
# Installing collected packages: deepctr
# Successfully installed deepctr-0.8.3
# 2021-01-09 18:34:23,775 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "train_steps": 10,
#         "model_dir": "/opt/ml/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tensorflow-training-2021-01-09-18-29-55-721",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-579019700964/tensorflow-training-2021-01-09-18-29-55-721/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 32,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"/opt/ml/model","train_steps":10}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=32
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-579019700964/tensorflow-training-2021-01-09-18-29-55-721/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"model_dir":"/opt/ml/model","train_steps":10},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2021-01-09-18-29-55-721","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-579019700964/tensorflow-training-2021-01-09-18-29-55-721/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":32,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--model_dir","/opt/ml/model","--train_steps","10"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_TRAIN_STEPS=10
# SM_HP_MODEL_DIR=/opt/ml/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.7 train.py --model_dir /opt/ml/model --train_steps 10
#
#
# gpus: 4
# [2021-01-09 18:34:31.464 ip-10-0-219-243.ec2.internal:85 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-01-09 18:34:31.464 ip-10-0-219-243.ec2.internal:85 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-01-09 18:34:31.464 ip-10-0-219-243.ec2.internal:85 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2021-01-09 18:34:31.465 ip-10-0-219-243.ec2.internal:85 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-01-09 18:34:31.579 ip-10-0-219-243.ec2.internal:85 INFO hook.py:382] Monitoring the collections: losses, metrics, sm_metrics
# Epoch 1/10
# 1/1 - 6s - loss: 0.7803 - binary_crossentropy: 0.7803 - val_loss: 0.7653 - val_binary_crossentropy: 0.7653 - batch: 0.0000e+00
# Epoch 2/10
# 1/1 - 0s - loss: 0.7573 - binary_crossentropy: 0.7573 - val_loss: 0.7510 - val_binary_crossentropy: 0.7510 - batch: 1.0000
# Epoch 3/10
# 1/1 - 0s - loss: 0.7352 - binary_crossentropy: 0.7352 - val_loss: 0.7374 - val_binary_crossentropy: 0.7374 - batch: 2.0000
# Epoch 4/10
# 1/1 - 0s - loss: 0.7140 - binary_crossentropy: 0.7139 - val_loss: 0.7243 - val_binary_crossentropy: 0.7243 - batch: 3.0000
# Epoch 5/10
# 1/1 - 0s - loss: 0.6935 - binary_crossentropy: 0.6935 - val_loss: 0.7117 - val_binary_crossentropy: 0.7117 - batch: 4.0000
# Epoch 6/10
# 1/1 - 0s - loss: 0.6738 - binary_crossentropy: 0.6738 - val_loss: 0.6994 - val_binary_crossentropy: 0.6994 - batch: 5.0000
# Epoch 7/10
# 1/1 - 0s - loss: 0.6545 - binary_crossentropy: 0.6545 - val_loss: 0.6874 - val_binary_crossentropy: 0.6874 - batch: 6.0000
# Epoch 8/10
# 1/1 - 0s - loss: 0.6356 - binary_crossentropy: 0.6356 - val_loss: 0.6756 - val_binary_crossentropy: 0.6756 - batch: 7.0000
# Epoch 9/10
# 1/1 - 0s - loss: 0.6169 - binary_crossentropy: 0.6169 - val_loss: 0.6643 - val_binary_crossentropy: 0.6643 - batch: 8.0000
# Epoch 10/10
# 1/1 - 0s - loss: 0.5984 - binary_crossentropy: 0.5983 - val_loss: 0.6532 - val_binary_crossentropy: 0.6532 - batch: 9.0000
# setting an array element with a sequence.
# setting an array element with a sequence.
# 2021-01-09 18:35:10,093 sagemaker_tensorflow_container.training WARNING  Your model will NOT be servable with SageMaker TensorFlow Serving container. The model artifact was not saved in the TensorFlow SavedModel directory structure:
# https://www.tensorflow.org/guide/saved_model#structure_of_a_savedmodel_directory
# 2021-01-09 18:35:10,093 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-01-09 18:35:23 Uploading - Uploading generated training model
# 2021-01-09 18:35:23 Completed - Training job completed
# Training seconds: 162
# Billable seconds: 162

# %% [markdown]
# ## Git Support

# %%
git_config = {'repo': 'https://github.com/whn09/deepctr_sagemaker.git', 'branch': 'main'}

estimator = TensorFlow(entry_point='train.py',
                       source_dir='.',
                       git_config=git_config,
                       train_instance_type='ml.p3.2xlarge', # Executes training in a ml.p2.xlarge instance
                       train_instance_count=1,
                       hyperparameters=hyperparameters,
                       role=role,
                       framework_version='2.2.0',
                       py_version='py37',
                       script_mode=True,
                       model_dir='/opt/ml/model')

estimator.fit({'training': inputs})
# Out:
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-01-09 18:38:55 Starting - Starting the training job...
# 2021-01-09 18:39:19 Starting - Launching requested ML instancesProfilerReport-1610217534: InProgress
# ......
# 2021-01-09 18:40:25 Starting - Preparing the instances for training.........
# 2021-01-09 18:41:49 Downloading - Downloading input data
# 2021-01-09 18:41:49 Training - Downloading the training image.........
# 2021-01-09 18:43:22 Training - Training image download completed. Training in progress..2021-01-09 18:43:20,787 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-01-09 18:43:21,167 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /usr/local/bin/python3.7 -m pip install -r requirements.txt
# Collecting deepctr[gpu]
#   Downloading deepctr-0.8.3-py3-none-any.whl (114 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (1.0.3)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/site-packages (from deepctr[gpu]->-r requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.7/site-packages (from deepctr[gpu]->-r requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu" in /usr/local/lib/python3.7/site-packages (from deepctr[gpu]->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (1.19.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (2020.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/site-packages (from sklearn->-r requirements.txt (line 3)) (0.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests->deepctr[gpu]->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests->deepctr[gpu]->-r requirements.txt (line 1)) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests->deepctr[gpu]->-r requirements.txt (line 1)) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests->deepctr[gpu]->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from h5py==2.10.0->deepctr[gpu]->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.35.1)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.12.1)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.3.3)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.13.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.31.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/site-packages (from tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/site-packages (from scikit-learn->sklearn->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.21.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.2.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.7.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (50.1.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in /usr/local/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (4.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.2.8)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/site-packages (from rsa<5,>=3.1.4; python_version >= "3.5"->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow-gpu!=1.7.*,!=1.8.*,>=1.4.0; extra == "gpu"->deepctr[gpu]->-r requirements.txt (line 1)) (3.1.0)
# Installing collected packages: deepctr
# Successfully installed deepctr-0.8.3
# 2021-01-09 18:43:22,774 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "train_steps": 10,
#         "model_dir": "/opt/ml/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tensorflow-training-2021-01-09-18-38-54-441",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-579019700964/tensorflow-training-2021-01-09-18-38-54-441/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"/opt/ml/model","train_steps":10}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-579019700964/tensorflow-training-2021-01-09-18-38-54-441/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"model_dir":"/opt/ml/model","train_steps":10},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2021-01-09-18-38-54-441","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-579019700964/tensorflow-training-2021-01-09-18-38-54-441/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--model_dir","/opt/ml/model","--train_steps","10"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_TRAIN_STEPS=10
# SM_HP_MODEL_DIR=/opt/ml/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.7 train.py --model_dir /opt/ml/model --train_steps 10
#
#
# gpus: 1
# [2021-01-09 18:43:30.366 ip-10-0-220-61.ec2.internal:37 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-01-09 18:43:30.366 ip-10-0-220-61.ec2.internal:37 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-01-09 18:43:30.366 ip-10-0-220-61.ec2.internal:37 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2021-01-09 18:43:30.366 ip-10-0-220-61.ec2.internal:37 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# Epoch 1/10
# [2021-01-09 18:43:30.498 ip-10-0-220-61.ec2.internal:37 INFO hook.py:382] Monitoring the collections: sm_metrics, metrics, losses
# 1/1 - 2s - loss: 0.7803 - binary_crossentropy: 0.7803 - val_loss: 0.7653 - val_binary_crossentropy: 0.7653 - batch: 0.0000e+00
# Epoch 2/10
# 1/1 - 0s - loss: 0.7573 - binary_crossentropy: 0.7573 - val_loss: 0.7510 - val_binary_crossentropy: 0.7510 - batch: 1.0000
# Epoch 3/10
# 1/1 - 0s - loss: 0.7352 - binary_crossentropy: 0.7352 - val_loss: 0.7374 - val_binary_crossentropy: 0.7374 - batch: 2.0000
# Epoch 4/10
# 1/1 - 0s - loss: 0.7140 - binary_crossentropy: 0.7139 - val_loss: 0.7243 - val_binary_crossentropy: 0.7243 - batch: 3.0000
# Epoch 5/10
# 1/1 - 0s - loss: 0.6935 - binary_crossentropy: 0.6935 - val_loss: 0.7117 - val_binary_crossentropy: 0.7117 - batch: 4.0000
# Epoch 6/10
# 1/1 - 0s - loss: 0.6738 - binary_crossentropy: 0.6738 - val_loss: 0.6994 - val_binary_crossentropy: 0.6994 - batch: 5.0000
# Epoch 7/10
# 1/1 - 0s - loss: 0.6545 - binary_crossentropy: 0.6545 - val_loss: 0.6874 - val_binary_crossentropy: 0.6874 - batch: 6.0000
# Epoch 8/10
# 1/1 - 0s - loss: 0.6356 - binary_crossentropy: 0.6356 - val_loss: 0.6756 - val_binary_crossentropy: 0.6756 - batch: 7.0000
# Epoch 9/10
# 1/1 - 0s - loss: 0.6169 - binary_crossentropy: 0.6169 - val_loss: 0.6643 - val_binary_crossentropy: 0.6643 - batch: 8.0000
# Epoch 10/10
# 1/1 - 0s - loss: 0.5984 - binary_crossentropy: 0.5983 - val_loss: 0.6532 - val_binary_crossentropy: 0.6532 - batch: 9.0000
# setting an array element with a sequence.
# setting an array element with a sequence.
# 2021-01-09 18:43:43,898 sagemaker_tensorflow_container.training WARNING  Your model will NOT be servable with SageMaker TensorFlow Serving container. The model artifact was not saved in the TensorFlow SavedModel directory structure:
# https://www.tensorflow.org/guide/saved_model#structure_of_a_savedmodel_directory
# 2021-01-09 18:43:43,898 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-01-09 18:43:56 Uploading - Uploading generated training model
# 2021-01-09 18:43:56 Completed - Training job completed
# Training seconds: 134
# Billable seconds: 134
